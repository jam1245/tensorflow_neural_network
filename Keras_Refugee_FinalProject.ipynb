# %% [markdown]
# ### CNN Image Classification Problem
#
# Identifying Refugee Camps in the Middle East
#
# Here the objective is to train a CNN on satellite images to identify refugee camps in the Middle East.  Here we are dealing with a real world problem and a limited amount of data.  We'll use a data augmentation feature to suplement our existing dataset.

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np 
# %matplotlib inline
import matplotlib.pyplot as plt
import os, sys
import itertools, functools
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import scale, LabelBinarizer
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.utils import class_weight
from skimage.io import imread, imshow
from skimage.transform import resize

# Random seed for numpy
np.random.seed(18937)
from keras.models import Model
from keras.layers import Input
from keras.layers.core import Dense, Dropout, Reshape
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions

import os
import argparse
from shutil import copy
from pathlib import Path
from multiprocessing import Pool, TimeoutError

# %%
# functions to create folders and copy files 
import os


def create_fold_dirs(output_path, num_folds):
    """
    Create train and test directories in output path
    :param output_path: Path to the output
    :param num_folds: the number of folds
    """
    for i in range(num_folds):
        for word in ["train", "test"]:
            os.mkdir(os.path.join(str(output_path), word + "_fold" + chr(65+i)))
    

def copy_file(file, source, output):
    f = file
    full_path = os.path.join(source, f)
    full_output= os.path.join(output, f)
    folder = full_output[:full_output.rfind("/")]
    if not Path(folder).exists():
        Path(folder).mkdir()
    if not Path(full_output).exists():
        print("Copying...{}".format(f))
        copy(full_path, full_output)

# %%
img_dir = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/Noncamp'
out_path2 = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/noncamp'
i = 0
for filename in os.listdir(img_dir):
    if filename.endswith("10.png"): 
        copy_file(filename, img_dir, out_path2)
        #print(os.path.join(img_dir, filename))
        continue
    else:
        continue  

#############################
#    i += 1
#    if i > 2050:
#        break  # otherwise the generator would loop indefinitely
# Out:
# Copying...noncamp,altinozu,36.35925,36.17987-chip10.png
# Copying...noncamp,altinozu,36.35925,36.18570-chip10.png
# Copying...noncamp,altinozu,36.37371,36.19153-chip10.png
# Copying...noncamp,altinozu,36.37371,36.18570-chip10.png
# Copying...noncamp,altinozu,36.37371,36.17987-chip10.png
# Copying...noncamp,altinozu,36.36648,36.19153-chip10.png
# Copying...noncamp,altinozu,36.36648,36.18570-chip10.png
# Copying...noncamp,altinozu,36.36648,36.17987-chip10.png
# Copying...noncamp,altinozu,36.35925,36.19153-chip10.png
# Copying...noncamp,apaydin,36.35856,36.23933-chip10.png
# Copying...noncamp,apaydin,36.35855,36.23349-chip10.png
# Copying...noncamp,apaydin,36.35855,36.22766-chip10.png
# Copying...noncamp,apaydin,36.35132,36.23933-chip10.png
# Copying...noncamp,apaydin,36.35132,36.23349-chip10.png
# Copying...noncamp,apaydin,36.35132,36.22766-chip10.png
# Copying...noncamp,apaydin,36.34409,36.23933-chip10.png
# Copying...noncamp,apaydin,36.34409,36.23349-chip10.png
# Copying...noncamp,apaydin,36.34409,36.22766-chip10.png
# Copying...noncamp,islahiye,36.61137,36.97753-chip10.png
# Copying...noncamp,islahiye,36.62597,36.98920-chip10.png
# Copying...noncamp,islahiye,36.62597,36.98337-chip10.png
# Copying...noncamp,islahiye,36.62597,36.97753-chip10.png
# Copying...noncamp,islahiye,36.61867,36.98920-chip10.png
# Copying...noncamp,islahiye,36.61867,36.98337-chip10.png
# Copying...noncamp,islahiye,36.61867,36.97753-chip10.png
# Copying...noncamp,islahiye,36.61137,36.98920-chip10.png
# Copying...noncamp,islahiye,36.61137,36.98337-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.96352,37.55875-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.96352,37.55292-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.98559,37.56458-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.98559,37.55875-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.96352,37.56458-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97824,37.57041-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97088,37.55875-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97823,37.56458-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97823,37.55875-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97823,37.55292-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97088,37.57041-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97088,37.56458-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.97088,37.55292-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.96352,37.57041-chip10.png
# Copying...noncamp,kara_tepe,26.54811,39.13152-chip10.png
# Copying...noncamp,kara_tepe,26.54059,39.12569-chip10.png
# Copying...noncamp,kara_tepe,26.54059,39.13152-chip10.png
# Copying...noncamp,king_abdullah_park,36.01925,32.52987-chip10.png
# Copying...noncamp,yayladagi,36.06385,35.91109-chip10.png
# Copying...noncamp,yayladagi,36.06385,35.90526-chip10.png
# Copying...noncamp,karkamis,38.02071,36.86882-chip10.png
# Copying...noncamp,karkamis,38.02801,36.87465-chip10.png
# Copying...noncamp,karkamis,38.03530,36.88048-chip10.png
# Copying...noncamp,karkamis,38.03530,36.87465-chip10.png
# Copying...noncamp,karkamis,38.03530,36.86882-chip10.png
# Copying...noncamp,karkamis,38.02801,36.88048-chip10.png
# Copying...noncamp,karkamis,38.02800,36.86882-chip10.png
# Copying...noncamp,karkamis,38.02071,36.88048-chip10.png
# Copying...noncamp,karkamis,38.02071,36.87465-chip10.png
# Copying...noncamp,king_abdullah_park,36.02617,32.52987-chip10.png
# Copying...noncamp,king_abdullah_park,36.02617,32.52403-chip10.png
# Copying...noncamp,king_abdullah_park,36.01925,32.52403-chip10.png
# Copying...noncamp,yayladagi,36.06385,35.89942-chip10.png
# Copying...noncamp,yayladagi,36.05665,35.90526-chip10.png
# Copying...noncamp,yayladagi,36.05665,35.91109-chip10.png
# Copying...noncamp,yayladagi,36.04944,35.90526-chip10.png
# Copying...noncamp,yayladagi,36.05664,35.89942-chip10.png
# Copying...noncamp,yayladagi,36.04944,35.91109-chip10.png
# Copying...noncamp,yayladagi,36.04944,35.89942-chip10.png
# Copying...noncamp,suruc,38.56681,36.92028-chip10.png
# Copying...noncamp,suruc,38.56681,36.91445-chip10.png
# Copying...noncamp,suruc,38.56681,36.90861-chip10.png
# Copying...noncamp,suruc,38.55952,36.91445-chip10.png
# Copying...noncamp,suruc,38.55222,36.90861-chip10.png
# Copying...noncamp,suruc,38.55952,36.92028-chip10.png
# Copying...noncamp,suruc,38.55222,36.91445-chip10.png
# Copying...noncamp,suruc,38.55952,36.90861-chip10.png
# Copying...noncamp,suruc,38.55222,36.92028-chip10.png
# Copying...noncamp,malatya_beydagi,38.17351,38.35624-chip10.png
# Copying...noncamp,malatya_beydagi,38.17351,38.35040-chip10.png
# Copying...noncamp,malatya_beydagi,38.17350,38.34457-chip10.png
# Copying...noncamp,malatya_beydagi,38.17350,38.33291-chip10.png
# Copying...noncamp,malatya_beydagi,38.17350,38.33874-chip10.png
# Copying...noncamp,malatya_beydagi,38.17349,38.32707-chip10.png
# Copying...noncamp,malatya_beydagi,38.16607,38.35624-chip10.png
# Copying...noncamp,malatya_beydagi,38.16607,38.34457-chip10.png
# Copying...noncamp,malatya_beydagi,38.16607,38.35040-chip10.png
# Copying...noncamp,malatya_beydagi,38.16606,38.32707-chip10.png
# Copying...noncamp,malatya_beydagi,38.15864,38.35624-chip10.png
# Copying...noncamp,malatya_beydagi,38.15863,38.35040-chip10.png
# Copying...noncamp,malatya_beydagi,38.15119,38.33291-chip10.png
# Copying...noncamp,malatya_beydagi,38.15863,38.34457-chip10.png
# Copying...noncamp,malatya_beydagi,38.15863,38.33291-chip10.png
# Copying...noncamp,malatya_beydagi,38.15120,38.35040-chip10.png
# Copying...noncamp,malatya_beydagi,38.15120,38.35624-chip10.png
# Copying...noncamp,malatya_beydagi,38.15862,38.32707-chip10.png
# Copying...noncamp,malatya_beydagi,38.15119,38.34457-chip10.png
# Copying...noncamp,malatya_beydagi,38.15119,38.32707-chip10.png
# Copying...noncamp,malatya_beydagi,38.15119,38.33874-chip10.png
# Copying...noncamp,malatya_beydagi,38.14376,38.35624-chip10.png
# Copying...noncamp,malatya_beydagi,38.14376,38.34457-chip10.png
# Copying...noncamp,malatya_beydagi,38.14376,38.33874-chip10.png
# Copying...noncamp,malatya_beydagi,38.14375,38.32707-chip10.png
# Copying...noncamp,malatya_beydagi,38.13632,38.35624-chip10.png
# Copying...noncamp,malatya_beydagi,38.14376,38.33291-chip10.png
# Copying...noncamp,malatya_beydagi,38.13632,38.34457-chip10.png
# Copying...noncamp,malatya_beydagi,38.13632,38.35040-chip10.png
# Copying...noncamp,malatya_beydagi,38.13632,38.33874-chip10.png
# Copying...noncamp,malatya_beydagi,38.12888,38.35624-chip10.png
# Copying...noncamp,malatya_beydagi,38.13632,38.33291-chip10.png
# Copying...noncamp,malatya_beydagi,38.12888,38.32707-chip10.png
# Copying...noncamp,malatya_beydagi,38.12888,38.33874-chip10.png
# Copying...noncamp,malatya_beydagi,38.12888,38.33291-chip10.png
# Copying...noncamp,malatya_beydagi,38.13632,38.32707-chip10.png
# Copying...noncamp,malatya_beydagi,38.12888,38.35040-chip10.png
# Copying...noncamp,malatya_beydagi,38.12888,38.34457-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.98559,37.57041-chip10.png
# Copying...noncamp,kahmanaras_turkoglu,36.98559,37.55292-chip10.png
# Copying...noncamp,kara_tepe,26.54811,39.12569-chip10.png

# %% [markdown]
# ## Data Augmentation

# %%
# this cell is not used in the model, just here to demonstrate how datagen works.  

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.0,
        zoom_range=0.0,
        horizontal_flip=True,
        fill_mode='nearest')

img = load_img('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/noncamp/noncamp,altinozu,36.35925,36.17987-chip10.png')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

print(x)

print(x.shape)

train = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/train'

# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir=train, save_prefix='camps', save_format='png'):
    i += 1
    if i > 50:
        break  # otherwise the generator would loop indefinitely

# %%
# let's take a peak at the files in the directory

obj =[]

import os
indir = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train/noncamp'
for root, dirs, filenames in os.walk(indir):
    for f in filenames:
        #print(f)
        obj = print(f)
# Out:
# noncamp,kahmanaras_turkoglu,36.97088,37.56458-chip05.png
# noncamp,altinozu,36.35925,36.17987-chip05.png
# noncamp,apaydin,36.35132,36.22766-chip05.png
# noncamp,apaydin,36.35132,36.23349-chip05.png
# noncamp,suruc,38.55222,36.90861-chip05.png
# noncamp,apaydin,36.34409,36.22766-chip05.png
# noncamp,islahiye,36.62597,36.97753-chip05.png
# noncamp,islahiye,36.62597,36.98337-chip05.png
# noncamp,suruc,38.55222,36.92028-chip05.png
# noncamp,islahiye,36.61867,36.97753-chip05.png
# noncamp,kahmanaras_turkoglu,36.98559,37.57041-chip05.png
# noncamp,suruc,38.55952,36.90861-chip05.png
# noncamp,kahmanaras_turkoglu,36.98559,37.55875-chip05.png
# noncamp,karkamis,38.02071,36.86882-chip05.png
# noncamp,kahmanaras_turkoglu,36.97823,37.55875-chip05.png
# noncamp,kahmanaras_turkoglu,36.97824,37.57041-chip05.png
# noncamp,karkamis,38.03530,36.86882-chip05.png
# noncamp,kahmanaras_turkoglu,36.96352,37.56458-chip05.png
# noncamp,kara_tepe,26.54811,39.12569-chip05.png
# noncamp,king_abdullah_park,36.01925,32.52403-chip05.png
# noncamp,malatya_beydagi,38.12888,38.34457-chip05.png
# noncamp,karkamis,38.03530,36.87465-chip05.png
# noncamp,suruc,38.55952,36.92028-chip05.png
# noncamp,suruc,38.55952,36.91445-chip05.png
# noncamp,karkamis,38.02071,36.87465-chip05.png
# noncamp,king_abdullah_park,36.02617,32.52403-chip05.png
# noncamp,malatya_beydagi,38.12888,38.33291-chip05.png
# noncamp,altinozu,36.36648,36.17987-chip05.png
# noncamp,altinozu,36.37371,36.19153-chip05.png
# noncamp,suruc,38.56681,36.90861-chip05.png
# noncamp,altinozu,36.37371,36.17987-chip05.png
# noncamp,suruc,38.56681,36.91445-chip05.png
# noncamp,altinozu,36.36648,36.18570-chip05.png
# noncamp,apaydin,36.34409,36.23349-chip05.png
# noncamp,apaydin,36.35855,36.22766-chip05.png
# noncamp,malatya_beydagi,38.12888,38.35040-chip05.png
# noncamp,islahiye,36.61137,36.97753-chip05.png
# noncamp,islahiye,36.61867,36.98337-chip05.png
# noncamp,kahmanaras_turkoglu,36.97823,37.55292-chip05.png
# noncamp,islahiye,36.61137,36.98920-chip05.png
# noncamp,kahmanaras_turkoglu,36.96352,37.55875-chip05.png
# noncamp,kahmanaras_turkoglu,36.97088,37.55875-chip05.png
# noncamp,kahmanaras_turkoglu,36.98559,37.55292-chip05.png
# noncamp,apaydin,36.35856,36.23933-chip05.png
# noncamp,kahmanaras_turkoglu,36.97088,37.55292-chip05.png
# noncamp,malatya_beydagi,38.13632,38.32707-chip05.png
# noncamp,kara_tepe,26.54059,39.12569-chip05.png
# noncamp,kara_tepe,26.54059,39.13152-chip05.png
# noncamp,karkamis,38.03530,36.88048-chip05.png
# noncamp,malatya_beydagi,38.12888,38.33874-chip05.png
# noncamp,karkamis,38.02801,36.88048-chip05.png
# noncamp,king_abdullah_park,36.02617,32.52987-chip05.png
# noncamp,king_abdullah_park,36.01925,32.52987-chip05.png
# noncamp,malatya_beydagi,38.13632,38.33291-chip05.png
# noncamp,yayladagi,36.06385,35.89942-chip05.png
# noncamp,yayladagi,36.05665,35.91109-chip05.png
# noncamp,yayladagi,36.05665,35.90526-chip05.png
# noncamp,yayladagi,36.05664,35.89942-chip05.png
# noncamp,yayladagi,36.04944,35.90526-chip05.png
# noncamp,malatya_beydagi,38.13632,38.33874-chip05.png
# noncamp,malatya_beydagi,38.16607,38.35624-chip05.png
# noncamp,malatya_beydagi,38.17350,38.34457-chip05.png
# noncamp,malatya_beydagi,38.15863,38.33291-chip05.png
# noncamp,malatya_beydagi,38.15863,38.34457-chip05.png
# noncamp,malatya_beydagi,38.15864,38.35624-chip05.png
# noncamp,malatya_beydagi,38.16607,38.35040-chip05.png
# noncamp,malatya_beydagi,38.17351,38.35624-chip05.png
# noncamp,malatya_beydagi,38.13632,38.34457-chip05.png
# noncamp,malatya_beydagi,38.13632,38.35040-chip05.png
# noncamp,malatya_beydagi,38.14375,38.32707-chip05.png
# noncamp,malatya_beydagi,38.14376,38.33291-chip05.png
# noncamp,malatya_beydagi,38.14376,38.33874-chip05.png
# noncamp,malatya_beydagi,38.14376,38.34457-chip05.png
# noncamp,malatya_beydagi,38.15119,38.32707-chip05.png
# noncamp,malatya_beydagi,38.15119,38.33291-chip05.png
# noncamp,malatya_beydagi,38.15119,38.33874-chip05.png
# noncamp,malatya_beydagi,38.15119,38.34457-chip05.png
# noncamp,malatya_beydagi,38.15863,38.35040-chip05.png
# noncamp,malatya_beydagi,38.16606,38.32707-chip05.png
# noncamp,malatya_beydagi,38.17350,38.33874-chip05.png

# %% [markdown]
# ### Let's examine some of the actual images

# %%
DATASET = lambda fname = '': os.path.join('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train', fname)
assert os.path.exists(DATASET())

plt.figure()

print("Showing the train/camp karkamis image, full path : {}".format(
            DATASET('camp/camp,karkamis,38.02801,36.87465-chip13.png')
        )
     )

imshow(imread(DATASET('camp/camp,karkamis,38.02801,36.87465-chip13.png')))
# Out:
# Showing the train/camp karkamis image, full path : /dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train/camp/camp,karkamis,38.02801,36.87465-chip13.png

# %% [markdown]
# #### Take a look at one of the noncamp images

# %%
imshow(imread(DATASET('noncamp/noncamp,apaydin,36.35856,36.23933-chip05.png')))
imread(DATASET('noncamp/noncamp,apaydin,36.35856,36.23933-chip05.png')).shape
# Out:
# (150, 150, 3)

# %%
import os

# count instances of noncamp in our training directory
DIR = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train/noncamp'
print("Noncamp Training Images:",len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))

# count instances of camp in our training directory
DIR = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train/camp'
print("Camp Training Images:",len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))


# count instances of noncamp in our testing directory
DIR = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/noncamp'
print("Noncamp Test Images",len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))

# count instances of camp in our testing directory
DIR = '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp'
print("Camp Test Images:",len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
# Out:
# Noncamp Training Images: 80
# Camp Training Images: 28
# Noncamp Test Images 40
# Camp Test Images: 11

# %% [markdown]
# ## Build our CNN Model

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

z = load_img('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/noncamp/noncamp,altinozu,36.35925,36.17987-chip10.png')  # this is a PIL image
x = img_to_array(z)  # this is a Numpy array with shape (3, 150, 150)
print(x.shape)

n_col = x.shape
print(n_col)

xt = np.transpose(x)
inputs = Input(shape=(784,))

n_col
# Out:
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense

datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(n_col))) # n_col is defined by the shape above 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
batch_size = 16

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
train_generator = train_datagen.flow_from_directory(
        '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 108 images belonging to 2 classes.
# Found 51 images belonging to 2 classes.

# %%
#class_weights = {0 : 1.,
#    1: 50.,
#    2: 2.}

#There are 74% images which are class 1, and 26% images which are class 0.  
#I balance 2 classes using the class_weights
class_weights = {0:74,1:26}

model.fit_generator(
        train_generator,
        steps_per_epoch=2881 // batch_size,
        epochs=10,
        class_weight=class_weights,
        validation_data=validation_generator,
        validation_steps=1184 // batch_size)
# model.save_weights('first_try.h5')  #  save weights after training or during training
# Out:
# Epoch 1/10
# 180/180 [==============================] - 74s - loss: 7.3700 - acc: 0.9059 - val_loss: 0.2716 - val_acc: 0.9411
# Epoch 2/10
# 180/180 [==============================] - 72s - loss: 2.2348 - acc: 0.9779 - val_loss: 0.1777 - val_acc: 0.9600
# Epoch 3/10
# 180/180 [==============================] - 72s - loss: 0.4111 - acc: 0.9947 - val_loss: 0.3867 - val_acc: 0.9611
# Epoch 4/10
# 180/180 [==============================] - 72s - loss: 2.2881 - acc: 0.9796 - val_loss: 0.3291 - val_acc: 0.9400
# Epoch 5/10
# 180/180 [==============================] - 72s - loss: 2.3519 - acc: 0.9801 - val_loss: 0.1855 - val_acc: 0.9611
# Epoch 6/10
# 180/180 [==============================] - 72s - loss: 0.3516 - acc: 0.9961 - val_loss: 0.2654 - val_acc: 0.9600
# Epoch 7/10
# 180/180 [==============================] - 72s - loss: 0.1923 - acc: 0.9990 - val_loss: 0.3505 - val_acc: 0.9611
# Epoch 8/10
# 180/180 [==============================] - 72s - loss: 1.1781 - acc: 0.9920 - val_loss: 0.2852 - val_acc: 0.9611
# Epoch 9/10
# 180/180 [==============================] - 72s - loss: 0.1299 - acc: 0.9997 - val_loss: 0.3952 - val_acc: 0.9611
# Epoch 10/10
# 180/180 [==============================] - 73s - loss: 0.2439 - acc: 0.9980 - val_loss: 0.3481 - val_acc: 0.9611

# %%
model.save_weights('first_try.h5')  #  save weights after training or during training

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_55 (Activation)   (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_56 (Activation)   (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_57 (Activation)   (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                1183808
# _________________________________________________________________
# activation_58 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_59 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluation
#
# ### Look at what the model is predicting
#
# Here we will load up some of the testing images and see if the model predicts that there is a refugee camp present or if there is no refugee camp.
#
# But first check the model accuracy and loss/error.  We will evaluate the model using  **validation_generator** to provide data.

# %%
loss, accuracy = model.evaluate_generator(validation_generator, steps = 800 // batch_size)
print('loss:', loss, 'accuracy:', accuracy)
# Out:
# loss: 0.352704033837 accuracy: 0.959627329193

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,malatya_beydagi,38.15119,38.33874-chip02.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/noncamp/noncamp,altinozu,36.35925,36.17987-chip10.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,karkamis,38.02801,36.87465-chip06.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,malatya_beydagi,38.15119,38.33874-chip00.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %% [markdown]
# The image above shows a small corner of a refugee camp.  Looks like there is just not enough features for the model to pick up that there is a refugee camp present in this image.

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,king_abdullah_park,36.02617,32.52987-chip16.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %% [markdown]
# Here we pull up another image where there's only a small portion of a refugee camp.  In this image the refugee camp is slightly more in the frame than the previous image, but it is still hard to tell that there is a refugee camp present.  Yet, in this situation the model picks up that there is a refugee camp present.

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,malatya_beydagi,38.15863,38.33874-chip06.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %% [markdown]
# The above image is a coner of a refugee camp.  It is hard to clearly tell if there is a refugee camp present in the image as not all the tents and lines are clear.  In this situation the model predicts that there is a refugee camp present.

# %% [markdown]
# ## Transfer Learning
#
# In the section below, we will transfer [VGG Networks](http://www.robots.ox.ac.uk/~vgg/research/very_deep/),
# [or academic paper: VGG16](https://arxiv.org/abs/1409.1556) network along with its
# weights instead of creating the neural network from scratch.
# But we will detach dense layers from VGG16 network and add our own.
# During training, all the weights within VGG16 will stay locked, so we'll be using
# whatever features VGG16 gives us.  Only weights in the dense layers will be trained, and this part serves as a classifier.

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

images = Input(shape = n_col) # (150,150,3) as shown above

vgg16 = VGG16(weights='imagenet', include_top=False)

# Lock the VGG16 Layers
for layer in vgg16.layers:
    layer.trainable = False   # Look above

classifier = [
    Flatten(input_shape = vgg16.output_shape[1:]),
    
    # Size, and Neuron Type
    Dense(256, activation='relu', name = 'dense_1'),
    Dropout(0.5),

    # Size, and Neuron Type
    Dense(1, activation='softmax', name = 'dense_2'),
]

y_pred = functools.reduce(lambda f1, f2: f2(f1), [images, vgg16]+classifier)

VGG16model = Model(inputs = [images], outputs = [y_pred])

# %%
VGG16model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(VGG16model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         (None, 150, 150, 3)       0
# _________________________________________________________________
# vgg16 (Model)                multiple                  14714688
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               2097408
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
batch_size = 16

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
        '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 108 images belonging to 2 classes.
# Found 51 images belonging to 2 classes.

# %%
#There are 74% images which are class 1, and 26% images which are class 0.  
#I balance 2 classes using the class_weights
class_weights = {0:74,1:26}

VGG16model.fit_generator(
        train_generator,
        steps_per_epoch=2881 // batch_size,
        epochs=10,
        class_weight=class_weights,
        validation_data=validation_generator,
        validation_steps=1184 // batch_size)
# model.save_weights('first_try.h5')  #  save weights after training or during training
# Out:
# Epoch 1/10
# 180/180 [==============================] - 479s - loss: 305.3127 - acc: 0.7412 - val_loss: 3.4234 - val_acc: 0.7853
# Epoch 2/10
# 180/180 [==============================] - 476s - loss: 305.7225 - acc: 0.7409 - val_loss: 3.4234 - val_acc: 0.7853
# Epoch 3/10
# 180/180 [==============================] - 493s - loss: 308.1667 - acc: 0.7388 - val_loss: 3.4234 - val_acc: 0.7853
# Epoch 4/10
# 180/180 [==============================] - 485s - loss: 306.8134 - acc: 0.7399 - val_loss: 3.4570 - val_acc: 0.7832
# Epoch 5/10
# 180/180 [==============================] - 485s - loss: 302.0468 - acc: 0.7440 - val_loss: 3.4066 - val_acc: 0.7863
# Epoch 6/10
# 180/180 [==============================] - 492s - loss: 305.4533 - acc: 0.7411 - val_loss: 3.4066 - val_acc: 0.7863
# Epoch 7/10
# 180/180 [==============================] - 494s - loss: 306.2657 - acc: 0.7404 - val_loss: 3.4234 - val_acc: 0.7853
# Epoch 8/10
# 180/180 [==============================] - 478s - loss: 304.6408 - acc: 0.7418 - val_loss: 3.4234 - val_acc: 0.7853
# Epoch 9/10
# 180/180 [==============================] - 484s - loss: 303.9502 - acc: 0.7424 - val_loss: 3.3899 - val_acc: 0.7874
# Epoch 10/10
# 180/180 [==============================] - 493s - loss: 306.9517 - acc: 0.7398 - val_loss: 3.4234 - val_acc: 0.7853

# %%
VGG16model.save_weights('VGG16model.h5')  #  save weights after training or during training

# %% [markdown]
# ### Evaluate the VGG Model

# %%
loss, accuracy = VGG16model.evaluate_generator(validation_generator, steps = 800 // batch_size)
print('loss:', loss, 'accuracy:', accuracy)
# Out:
# loss: 3.41622542298 accuracy: 0.785714286316

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,malatya_beydagi,38.15119,38.33874-chip02.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = VGG16model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,karkamis,38.02801,36.87465-chip08.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = VGG16model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/noncamp/noncamp,altinozu,36.35925,36.17987-chip10.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = VGG16model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,king_abdullah_park,36.02617,32.52987-chip16.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = VGG16model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,malatya_beydagi,38.15863,38.33874-chip06.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = VGG16model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,karkamis,38.02801,36.87465-chip12.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = VGG16model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K

# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)

# Lock the Layers
for layer in base_model.layers:
    layer.trainable = False   
classifier = [
    Flatten(input_shape = resnet.output_shape[1:]),
    
    # Size, and Neuron Type
    Dense(256, activation='relu', name = 'dense_1'),
    Dropout(0.5),

    # Size, and Neuron Type
    Dense(1, activation='sigmoid', name = 'dense_2'),
]

y_pred = functools.reduce(lambda f1, f2: f2(f1), [images, base_model]+classifier)

incept_model = Model(inputs = [images], outputs = [y_pred])
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 86032384/87910968 [============================>.] - ETA: 0s

# %%
incept_model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(incept_model.summary())

batch_size = 16

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
        '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_train',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        '/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        (None, 150, 150, 3)       0
# _________________________________________________________________
# inception_v3 (Model)         multiple                  21802784
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 18432)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 26,521,889
# Trainable params: 4,719,105
# Non-trainable params: 21,802,784
# _________________________________________________________________
# None
# Found 108 images belonging to 2 classes.
# Found 51 images belonging to 2 classes.

# %%
incept_model.fit_generator(
        train_generator,
        steps_per_epoch=2881 // batch_size,
        epochs=10,
        class_weight=class_weights,
        validation_data=validation_generator,
        validation_steps=1184 // batch_size)
# Out:
# Epoch 1/10
# 180/180 [==============================] - 166s - loss: 44.3917 - acc: 0.8529 - val_loss: 1.1550 - val_acc: 0.8621
# Epoch 2/10
# 180/180 [==============================] - 162s - loss: 20.5608 - acc: 0.9277 - val_loss: 2.3191 - val_acc: 0.7863
# Epoch 3/10
# 180/180 [==============================] - 166s - loss: 16.4358 - acc: 0.9384 - val_loss: 1.1211 - val_acc: 0.8821
# Epoch 4/10
# 180/180 [==============================] - 162s - loss: 7.1521 - acc: 0.9494 - val_loss: 0.5902 - val_acc: 0.9411
# Epoch 5/10
# 180/180 [==============================] - 164s - loss: 3.1592 - acc: 0.9705 - val_loss: 0.6893 - val_acc: 0.8842
# Epoch 6/10
# 180/180 [==============================] - 162s - loss: 4.8092 - acc: 0.9655 - val_loss: 0.6572 - val_acc: 0.9011
# Epoch 7/10
# 180/180 [==============================] - 158s - loss: 4.8680 - acc: 0.9656 - val_loss: 0.5499 - val_acc: 0.8621
# Epoch 8/10
# 180/180 [==============================] - 159s - loss: 2.6602 - acc: 0.9775 - val_loss: 0.5084 - val_acc: 0.9042
# Epoch 9/10
# 180/180 [==============================] - 157s - loss: 2.5739 - acc: 0.9802 - val_loss: 0.6096 - val_acc: 0.9011
# Epoch 10/10
# 180/180 [==============================] - 157s - loss: 3.2932 - acc: 0.9705 - val_loss: 0.5264 - val_acc: 0.8842

# %%
incept_model.save_weights('incept_model.h5')  #  save weights

# %%
loss, accuracy = incept_model.evaluate_generator(validation_generator, steps = 800 // batch_size)
print('loss:', loss, 'accuracy:', accuracy)
# Out:
# loss: 0.538425774106 accuracy: 0.880434782701

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,malatya_beydagi,38.15119,38.33874-chip02.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = incept_model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,karkamis,38.02801,36.87465-chip08.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = incept_model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/noncamp/noncamp,altinozu,36.35925,36.17987-chip10.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = incept_model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,king_abdullah_park,36.02617,32.52987-chip16.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = incept_model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,malatya_beydagi,38.15119,38.33874-chip00.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = incept_model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Noncamp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/part,malatya_beydagi,38.15863,38.33874-chip06.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = incept_model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp

# %%
im_test = imread(DATASET('/dsa/home/jamgtn/experimental/data/refugee_camp_data/n_test/camp/camp,karkamis,38.02801,36.87465-chip12.png'))
imshow(im_test)
im_test = resize(im_test, (150, 150), mode = 'reflect')
y_pred = incept_model.predict(np.expand_dims(im_test, 0)).squeeze()
print(['Refugee Camp', 'Noncamp'][y_pred>=0.5])
# Out:
# Refugee Camp
